# %%
import hydropandas as hpd

# %%
hpd.read_knmi_scenarios("550")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 hpd.read_knmi_scenarios(
#       2     "550",
#       3     years=["2050", "2100"],
#       4     scenarios=["Md", "Hd"],
#       5     evap="Makkink",
#       6     name="De Bilt Climate Scenarios"
#       7 )
#
# AttributeError: module 'hydropandas' has no attribute 'read_knmi_scenarios'
